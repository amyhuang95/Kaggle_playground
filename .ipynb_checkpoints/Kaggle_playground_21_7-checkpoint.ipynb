# %%
# importing packages for EDA

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
# importing data

df = pd.read_csv('https://raw.githubusercontent.com/JosefRein/Kaggle_playground/main/train.csv')
df.shape
# Out:
# (7111, 12)

# %%
# date_time is encoded as an object, not a date
# Fixing that

df.date_time = pd.to_datetime(df.date_time)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7111 entries, 0 to 7110
# Data columns (total 12 columns):
# date_time                 7111 non-null datetime64[ns]
# deg_C                     7111 non-null float64
# relative_humidity         7111 non-null float64
# absolute_humidity         7111 non-null float64
# sensor_1                  7111 non-null float64
# sensor_2                  7111 non-null float64
# sensor_3                  7111 non-null float64
# sensor_4                  7111 non-null float64
# sensor_5                  7111 non-null float64
# target_carbon_monoxide    7111 non-null float64
# target_benzene            7111 non-null float64
# target_nitrogen_oxides    7111 non-null float64
# dtypes: datetime64[ns](1), float64(11)
# memory usage: 666.8 KB

# %%
df.head()
# Out:
#             date_time  deg_C  relative_humidity  absolute_humidity  sensor_1  \
# 0 2010-03-10 18:00:00   13.1               46.0             0.7578    1387.2
# 1 2010-03-10 19:00:00   13.2               45.3             0.7255    1279.1
# 2 2010-03-10 20:00:00   12.6               56.2             0.7502    1331.9
# 3 2010-03-10 21:00:00   11.0               62.4             0.7867    1321.0
# 4 2010-03-10 22:00:00   11.9               59.0             0.7888    1272.0
#
#    sensor_2  sensor_3  sensor_4  sensor_5  target_carbon_monoxide  \
# 0    1087.8    1056.0    1742.8    1293.4                     2.5
# 1     888.2    1197.5    1449.9    1010.9                     2.1
# 2     929.6    1060.2    1586.1    1117.0                     2.2
# 3     929.0    1102.9    1536.5    1263.2                     2.2
# 4     852.7    1180.9    1415.5    1132.2                     1.5
#
#    target_benzene  target_nitrogen_oxides
# 0            12.0                   167.7
# ...

# %%
df.describe().T #transpose to get a better view of the output
# Out:
#                          count         mean         std       min        25%  \
# deg_C                   7111.0    20.878034    7.937917    1.3000    14.9000
# relative_humidity       7111.0    47.561004   17.398731    8.9000    33.7000
# absolute_humidity       7111.0     1.110309    0.398950    0.1988     0.8559
# sensor_1                7111.0  1091.572100  218.537554  620.3000   930.2500
# sensor_2                7111.0   938.064970  281.978988  364.0000   734.9000
# sensor_3                7111.0   883.903305  310.456355  310.6000   681.0500
# sensor_4                7111.0  1513.238349  350.180310  552.9000  1320.3500
# sensor_5                7111.0   998.335565  381.537695  242.7000   722.8500
# target_carbon_monoxide  7111.0     2.086219    1.447109    0.1000     1.0000
# target_benzene          7111.0    10.237083    7.694426    0.1000     4.5000
# target_nitrogen_oxides  7111.0   204.066784  193.927723    1.9000    76.4500
#
# ...
